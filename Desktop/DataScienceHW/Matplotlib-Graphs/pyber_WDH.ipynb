# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

#See city data
city_data.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
#ride data
ride_data.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2018-03-09 06:26:29  42.81  5327642267789

# %%
# Combine the data into a single dataset

combined_ride_data = pd.merge(city_data, ride_data, how="left", on="city")

# Display the data table for preview
combined_ride_data.head(10)
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850
# 5  Richardfort            38  Urban  2018-04-21 03:44:04   9.54  3698147103219
# 6  Richardfort            38  Urban  2018-02-03 00:14:26  29.04  4982665519010
# 7  Richardfort            38  Urban  2018-02-08 15:50:12  16.55  2270463070874
# 8  Richardfort            38  Urban  2018-04-03 15:07:34  40.77  9496210735824
# 9  Richardfort            38  Urban  2018-02-19 14:09:20  27.11  8690324801449

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

combineRide = combined_ride_data["type"] == "Urban"
urban_cities = combined_ride_data[combineRide]
print(urban_cities.head())
urbanCitiesGroupby=urban_cities.groupby(["city"])
urbanCitiesGroupby.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850
#                     city  driver_count   type                 date   fare  \
# 0            Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1            Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2            Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3            Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4            Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# ...

# %%
combineRide2 = combined_ride_data["type"] == "Suburban"
suburban_cities = combined_ride_data[combineRide2]
print(suburban_cities.head())
suburbanCitiesGroupby=urban_cities.groupby(["city"])
suburbanCitiesGroupby.head()
# Out:
#             city  driver_count      type                 date   fare  \
# 1625  Port Shane             7  Suburban  2018-04-09 15:34:40  27.66
# 1626  Port Shane             7  Suburban  2018-04-23 16:05:47  42.26
# 1627  Port Shane             7  Suburban  2018-03-02 12:06:00  14.95
# 1628  Port Shane             7  Suburban  2018-03-26 04:33:30  19.03
# 1629  Port Shane             7  Suburban  2018-03-15 12:09:42  31.58
#
#             ride_id
# 1625  4022340141966
# 1626  8341982666719
# 1627  2803204948363
# 1628  6010401984537
# 1629  2552978514662
#                     city  driver_count   type                 date   fare  \
# 0            Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1            Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2            Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3            Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# ...

# %%
combineRide3 = combined_ride_data["type"] == "Rural"
rural_cities = combined_ride_data[combineRide3]
print(rural_cities.head())
ruralCitiesGroupby=urban_cities.groupby(["city"])
ruralCitiesGroupby.head()
# Out:
#                 city  driver_count   type                 date   fare  \
# 2250  South Jennifer             7  Rural  2018-04-01 09:32:45  21.63
# 2251  South Jennifer             7  Rural  2018-03-07 19:10:13  48.79
# 2252  South Jennifer             7  Rural  2018-04-05 14:35:42  32.20
# 2253  South Jennifer             7  Rural  2018-04-02 10:26:50  14.11
# 2254  South Jennifer             7  Rural  2018-04-10 20:46:11  43.25
#
#             ride_id
# 2250  9135979586871
# 2251  9730627367446
# 2252   683983658392
# 2253  3828267773041
# 2254   623928772332
#                     city  driver_count   type                 date   fare  \
# 0            Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1            Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2            Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3            Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# ...

# %%
# Build the scatter plots for each city types

dotSize=10
alphaC=.25
dotSizeL=40


plt.scatter(urban_cities,
           urban_avg_fare,
           s=dotSize*urban_drive_count, C="blue",
           edgecolor="black", linewideths=1, marker="0",
           alph=alphaC, label="Urban")

plt.scatter(suburban_cities,
           suburban_avg_fare,
           s=dotSize*suburban_drive_count, C="red",
           edgecolor="black", linewideths=1, marker="0",
           alph=alphaC, label="Suburban")

plt.scatter(rural_cities,
           rural_avg_fare,
           s=dotSize*urban_drive_count, C="green",
           edgecolor="black", linewideths=1, marker="0",
           alph=alphaC, label="Rural")


# Incorporate the other graph properties
plt.title("Pyber Ride Sharing Data")
plt.ylabel("Average Fare")
plt.xlabel("Total number of rides per city")
plt.xlim(0.45)
plt.grid(True)


# Create a legend
lgnd = plt.legend()(frontsize="small", numpoints=1, scatterpoints=1,
                    loc="best", title="City Types",
                    labelspacing=0.5)
lgnd.legendhandles[0]._sizes = [30]
lgnd.legendhandles[1]._sizes = [30]
lgnd.legendhandles[2]._sizes = [30]


# Incorporate a text label regarding circle size
plt.text(40,35)

# Save Figure
plt.savefig("ridesharingdata/fig1.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5fccea7aeca6> in <module>()
#       7
#       8 plt.scatter(urban_cities,
# ----> 9            urban_avg_fare,
#      10            s=dotSize*urban_drive_count, C="blue",
#      11            edgecolor="black", linewideths=1, marker="0",
#
# NameError: name 'urban_avg_fare' is not defined

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
ride_percents = 100 * city_ride_data.groupby`(["type"]).count()["ride_id"] / city_ride_data["ride_id"].count()
typeC=ride_percents.index.tolist()

# Build Pie Chart
plt.pie(ride_percents,
       labels=typeC,
       colors["gold", "lightskyblue", "coral"],
       explode = [0,0, 0.1],
       autopct = '%1.1f%%',
       shadow=True, startange=90)
plt.title("% of Total Fares by City Type")
# Save Figure
plt.savefig("data/fig2.png")
# Out:
#   File "<ipython-input-24-b96c62ecfff8>", line 2
#     ride_percents = 100 * city_ride_data.groupby`(["type"]).count()["ride_id"] / city_ride_data["ride_id"].count()
#                                                 ^
# SyntaxError: invalid syntax

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Type Percents
ride_percents = 100 * city_ride_data.groupby`(["type"]).count()["ride_id"] / city_ride_data["ride_id"].count()
typeC=ride_percents.index.tolist()

# Build Pie Chart
plt.pie(ride_percents,
       labels=typeC,
       colors["gold", "lightskyblue", "coral"],
       explode = [0,0, 0.1],
       autopct = '%1.1f%%',
       shadow=True, startange=90)
plt.title("% of Total Rides by City Type")
# Save Figure
plt.savefig("data/fig3.png")
# Out:
#   File "<ipython-input-26-79599e900337>", line 2
#     ride_percents = 100 * city_ride_data.groupby`(["type"]).count()["ride_id"] / city_ride_data["ride_id"].count()
#                                                 ^
# SyntaxError: invalid syntax

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Type Percents
driver_percents = 100 * city_data.groupby`(["type"]).count()["driver_count"] / city_data["driver_count"].sum()
typeC=driver_percents.index.tolist()

# Build Pie Chart
plt.pie(ride_percents,
       labels=typeC,
       colors["gold", "lightskyblue", "coral"],
       explode = [0,0, 0.1],
       autopct = '%1.1f%%',
       shadow=True, startange=90)
plt.title("% of Total Drivers by City Type")
# Save Figure
plt.savefig("data/fig4.png")
# Out:
#   File "<ipython-input-28-7f646024001d>", line 2
#     driver_percents = 100 * city_data.groupby`(["type"]).count()["driver_count"] / city_data["driver_count"].sum()
#                                              ^
# SyntaxError: invalid syntax

# %%
# Show Figure
plt.show()
